# %%
import urllib.request, json 
product=dict()

with urllib.request.urlopen("https://api.etorostatic.com/sapi/instrumentsmetadata/V1.1/instruments?cv=f533225eb8edff28f28f448b15f55486_ccf1dd923418a7527712207498d5c0d9") as url:
    data = json.loads(url.read().decode())

product["ETF"] = 6

for ticker in data["InstrumentDisplayDatas"]:
  if ticker['InstrumentTypeID'] == product["ETF"]:
    print(ticker)
# Out:
# {'InstrumentID': 3000, 'InstrumentDisplayName': 'SPDR S&P 500 ETF', 'InstrumentTypeID': 6, 'ExchangeID': 5, 'Images': [{'Width': 35.0, 'Height': 35.0, 'Uri': 'https://etoro-cdn.etorostatic.com/market-avatars/spy/35x35.png'}, {'Width': 50.0, 'Height': 50.0, 'Uri': 'https://etoro-cdn.etorostatic.com/market-avatars/spy/50x50.png'}, {'Width': 80.0, 'Height': 80.0, 'Uri': 'https://etoro-cdn.etorostatic.com/market-avatars/spy/80x80.png'}, {'Width': 90.0, 'Height': 90.0, 'Uri': 'https://etoro-cdn.etorostatic.com/market-avatars/spy/90x90.png'}, {'Width': 150.0, 'Height': 150.0, 'Uri': 'https://etoro-cdn.etorostatic.com/market-avatars/spy/150x150.png'}], 'SymbolFull': 'SPY', 'StocksIndustryID': 0, 'PriceSource': 'Xignite'}
# ...
